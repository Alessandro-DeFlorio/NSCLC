# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.segmentation import clear_border
from skimage.measure import label, regionprops
from scipy.ndimage import measurements, center_of_mass, binary_dilation, zoom, binary_fill_holes
import nibabel as nib
from tqdm.notebook import tqdm

import os

ct_path = r"D:\nsclc\data\nnUNet_raw\Dataset002_Thesis\imagesTr"
mask_path = r"D:\nsclc\data\nnUNet_raw\Dataset002_Thesis\lung_extraction"
output_path = r"D:\nsclc\data\nnUNet_raw\Dataset002_Thesis\processed"

#check if output path exists, if not create it
if not os.path.exists(output_path):
    print("e' 'a 'ra maronna, ma quant' si cciot? 'statt quet 'n'attimo ca nn' stej creann 'u \"path\"")
    os.makedirs(output_path)
#get files sorted
ct_files = sorted(os.listdir(ct_path))
for i in tqdm(range(len(ct_files)), colour='green', desc='isolating lungs, I hope...'):
    #check if the file already exists
    if os.path.exists(os.path.join(output_path, ct_files[i])):
        print(f"{ct_files[i]} already exists, skipping...")
        continue
    print(f"processing {ct_files[i]}")
    ct = nib.load(os.path.join(ct_path, ct_files[i]))
    mask = nib.load(os.path.join(mask_path, ct_files[i]))
    ct_data = ct.get_fdata()
    mask_data = mask.get_fdata()
    mask_data = mask_data.astype(bool)

    #get minimum value in ct
    min_val = np.min(ct_data)
    # add min value to mask to avoid negative values
    ct_data = ct_data - min_val

    #hadamaard product between mask and ct
    masked_ct = ct_data * mask_data # these are the lungs isolated

    # return to original values
    masked_ct = masked_ct + min_val

    # save using same affine and header as original ct
    masked_ct_nii = nib.Nifti1Image(masked_ct, ct.affine, ct.header)
    nib.save(masked_ct_nii, os.path.join(output_path, ct_files[i]))
print('done')
# Out:
# isolating lungs, I hope...:   0%|          | 0/294 [00:00<?, ?it/s]
# INT1010016_0000.nii.gz already exists, skipping...
# INT1010023_0000.nii.gz already exists, skipping...
# INT1010024_0000.nii.gz already exists, skipping...
# INT1010030_0000.nii.gz already exists, skipping...
# INT1010031_0000.nii.gz already exists, skipping...
# INT1010034_0000.nii.gz already exists, skipping...
# INT1010037_0000.nii.gz already exists, skipping...
# INT1010038_0000.nii.gz already exists, skipping...
# INT1010040_0000.nii.gz already exists, skipping...
# INT1010044_0000.nii.gz already exists, skipping...
# INT1010045_0000.nii.gz already exists, skipping...
# INT1010048_0000.nii.gz already exists, skipping...
# INT1010050_0000.nii.gz already exists, skipping...
# INT1010053_0000.nii.gz already exists, skipping...
# INT1010055_0000.nii.gz already exists, skipping...
# INT1010056_0000.nii.gz already exists, skipping...
# INT1010061_0000.nii.gz already exists, skipping...
# INT1010066_0000.nii.gz already exists, skipping...
# INT1010069_0000.nii.gz already exists, skipping...
# INT1010071_0000.nii.gz already exists, skipping...
# INT1010072_0000.nii.gz already exists, skipping...
# INT1010073_0000.nii.gz already exists, skipping...
# INT1010074_0000.nii.gz already exists, skipping...
# INT1010077_0000.nii.gz already exists, skipping...
# INT1010079_0000.nii.gz already exists, skipping...
# INT1010089_0000.nii.gz already exists, skipping...
# INT1010090_0000.nii.gz already exists, skipping...
# INT1010099_0000.nii.gz already exists, skipping...
# INT1010105_0000.nii.gz already exists, skipping...
# INT1010109_0000.nii.gz already exists, skipping...
# INT1010111_0000.nii.gz already exists, skipping...
# INT1010112_0000.nii.gz already exists, skipping...
# INT1010125_0000.nii.gz already exists, skipping...
# INT1010126_0000.nii.gz already exists, skipping...
# INT1010127_0000.nii.gz already exists, skipping...
# INT1010153_0000.nii.gz already exists, skipping...
# INT1010158_0000.nii.gz already exists, skipping...
# INT1010159_0000.nii.gz already exists, skipping...
# INT1010161_0000.nii.gz already exists, skipping...
# INT1010163_0000.nii.gz already exists, skipping...
# INT1010168_0000.nii.gz already exists, skipping...
# INT1010169_0000.nii.gz already exists, skipping...
# INT1010175_0000.nii.gz already exists, skipping...
# INT1010176_0000.nii.gz already exists, skipping...
# INT1010178_0000.nii.gz already exists, skipping...
# INT1010181_0000.nii.gz already exists, skipping...
# INT1010182_0000.nii.gz already exists, skipping...
# INT1010194_0000.nii.gz already exists, skipping...
# INT1010204_0000.nii.gz already exists, skipping...
# INT1010209_0000.nii.gz already exists, skipping...
# INT1010212_0000.nii.gz already exists, skipping...
# INT1010213_0000.nii.gz already exists, skipping...
# INT1010214_0000.nii.gz already exists, skipping...
# INT1010216_0000.nii.gz already exists, skipping...
# INT1010217_0000.nii.gz already exists, skipping...
# INT1010218_0000.nii.gz already exists, skipping...
# INT1010219_0000.nii.gz already exists, skipping...
# INT1010220_0000.nii.gz already exists, skipping...
# INT1010221_0000.nii.gz already exists, skipping...
# INT1010222_0000.nii.gz already exists, skipping...
# INT1010224_0000.nii.gz already exists, skipping...
# INT1010225_0000.nii.gz already exists, skipping...
# INT1010226_0000.nii.gz already exists, skipping...
# INT1010228_0000.nii.gz already exists, skipping...
# INT1010231_0000.nii.gz already exists, skipping...
# INT1010232_0000.nii.gz already exists, skipping...
# INT1010234_0000.nii.gz already exists, skipping...
# INT1010236_0000.nii.gz already exists, skipping...
# INT1010238_0000.nii.gz already exists, skipping...
# INT1010239_0000.nii.gz already exists, skipping...
# INT1010240_0000.nii.gz already exists, skipping...
# INT1010241_0000.nii.gz already exists, skipping...
# INT1010247_0000.nii.gz already exists, skipping...
# INT1010248_0000.nii.gz already exists, skipping...
# INT1010249_0000.nii.gz already exists, skipping...
# INT1010250_0000.nii.gz already exists, skipping...
# INT1010251_0000.nii.gz already exists, skipping...
# INT1010252_0000.nii.gz already exists, skipping...
# INT1010253_0000.nii.gz already exists, skipping...
# INT1010255_0000.nii.gz already exists, skipping...
# INT1010257_0000.nii.gz already exists, skipping...
# INT1010259_0000.nii.gz already exists, skipping...
# INT1010261_0000.nii.gz already exists, skipping...
# INT1010263_0000.nii.gz already exists, skipping...
# INT1010264_0000.nii.gz already exists, skipping...
# INT1010265_0000.nii.gz already exists, skipping...
# INT1010268_0000.nii.gz already exists, skipping...
# INT1010269_0000.nii.gz already exists, skipping...
# INT1010270_0000.nii.gz already exists, skipping...
# INT1010272_0000.nii.gz already exists, skipping...
# INT1010275_0000.nii.gz already exists, skipping...
# INT1010277_0000.nii.gz already exists, skipping...
# INT1010278_0000.nii.gz already exists, skipping...
# INT1010279_0000.nii.gz already exists, skipping...
# INT1010283_0000.nii.gz already exists, skipping...
# INT1010285_0000.nii.gz already exists, skipping...
# INT1010286_0000.nii.gz already exists, skipping...
# INT1010287_0000.nii.gz already exists, skipping...
# INT1010288_0000.nii.gz already exists, skipping...
# INT1010289_0000.nii.gz already exists, skipping...
# INT1010291_0000.nii.gz already exists, skipping...
# INT1010293_0000.nii.gz already exists, skipping...
# INT1010294_0000.nii.gz already exists, skipping...
# INT1010295_0000.nii.gz already exists, skipping...
# INT1010297_0000.nii.gz already exists, skipping...
# INT1010298_0000.nii.gz already exists, skipping...
# INT1010301_0000.nii.gz already exists, skipping...
# INT1010302_0000.nii.gz already exists, skipping...
# INT1010307_0000.nii.gz already exists, skipping...
# INT1010308_0000.nii.gz already exists, skipping...
# INT1010309_0000.nii.gz already exists, skipping...
# INT1010310_0000.nii.gz already exists, skipping...
# INT1010314_0000.nii.gz already exists, skipping...
# INT1010316_0000.nii.gz already exists, skipping...
# INT1010319_0000.nii.gz already exists, skipping...
# INT1010320_0000.nii.gz already exists, skipping...
# INT1010321_0000.nii.gz already exists, skipping...
# INT1010323_0000.nii.gz already exists, skipping...
# INT1010325_0000.nii.gz already exists, skipping...
# INT1010326_0000.nii.gz already exists, skipping...
# INT1010327_0000.nii.gz already exists, skipping...
# INT1010328_0000.nii.gz already exists, skipping...
# INT1010329_0000.nii.gz already exists, skipping...
# INT1010330_0000.nii.gz already exists, skipping...
# INT1010331_0000.nii.gz already exists, skipping...
# INT1010332_0000.nii.gz already exists, skipping...
# INT1010335_0000.nii.gz already exists, skipping...
# INT1010337_0000.nii.gz already exists, skipping...
# INT1010338_0000.nii.gz already exists, skipping...
# INT1010340_0000.nii.gz already exists, skipping...
# INT1010342_0000.nii.gz already exists, skipping...
# INT1010344_0000.nii.gz already exists, skipping...
# INT1010346_0000.nii.gz already exists, skipping...
# INT1010347_0000.nii.gz already exists, skipping...
# INT1010348_0000.nii.gz already exists, skipping...
# INT1010353_0000.nii.gz already exists, skipping...
# INT1010355_0000.nii.gz already exists, skipping...
# INT1010356_0000.nii.gz already exists, skipping...
# INT1010359_0000.nii.gz already exists, skipping...
# INT1010361_0000.nii.gz already exists, skipping...
# INT1010364_0000.nii.gz already exists, skipping...
# INT1010365_0000.nii.gz already exists, skipping...
# INT1010366_0000.nii.gz already exists, skipping...
# INT1010367_0000.nii.gz already exists, skipping...
# INT1010368_0000.nii.gz already exists, skipping...
# INT1010369_0000.nii.gz already exists, skipping...
# INT1010370_0000.nii.gz already exists, skipping...
# INT1010372_0000.nii.gz already exists, skipping...
# INT1010374_0000.nii.gz already exists, skipping...
# processing INT1010375_0000.nii.gz
# processing INT1010376_0000.nii.gz
# processing INT1010378_0000.nii.gz
# processing INT1010380_0000.nii.gz
# processing INT1010383_0000.nii.gz
# processing INT1010384_0000.nii.gz
# processing INT1010385_0000.nii.gz
# processing INT1010387_0000.nii.gz
# processing INT1010389_0000.nii.gz
# processing INT1010391_0000.nii.gz
# processing INT1010392_0000.nii.gz
# processing INT1010393_0000.nii.gz
# processing INT1010394_0000.nii.gz
# processing INT1010396_0000.nii.gz
# processing INT1010397_0000.nii.gz
# processing INT1010398_0000.nii.gz
# processing INT1010399_0000.nii.gz
# processing INT1010400_0000.nii.gz
# processing INT1010401_0000.nii.gz
# processing INT1010402_0000.nii.gz
# processing INT1010403_0000.nii.gz
# processing INT1010404_0000.nii.gz
# processing INT1010405_0000.nii.gz
# processing INT1010406_0000.nii.gz
# processing INT1010407_0000.nii.gz
# processing INT1010409_0000.nii.gz
# processing INT1010410_0000.nii.gz
# processing INT1010411_0000.nii.gz
# processing INT1010412_0000.nii.gz
# processing INT1010413_0000.nii.gz
# processing INT1010417_0000.nii.gz
# processing INT1010419_0000.nii.gz
# processing INT1010420_0000.nii.gz
# processing INT1010421_0000.nii.gz
# processing INT1010422_0000.nii.gz
# processing INT1010423_0000.nii.gz
# processing INT1010426_0000.nii.gz
# processing INT1010427_0000.nii.gz
# processing INT1010428_0000.nii.gz
# processing INT1010430_0000.nii.gz
# processing INT1010431_0000.nii.gz
# processing INT1010432_0000.nii.gz
# processing INT1010435_0000.nii.gz
# processing INT1010437_0000.nii.gz
# processing INT1010438_0000.nii.gz
# processing INT1010440_0000.nii.gz
# processing INT1010441_0000.nii.gz
# processing INT1010444_0000.nii.gz
# processing INT1010445_0000.nii.gz
# processing INT1010447_0000.nii.gz
# processing INT1010448_0000.nii.gz
# processing INT1010450_0000.nii.gz
# processing INT1010451_0000.nii.gz
# processing INT1010452_0000.nii.gz
# processing INT1010453_0000.nii.gz
# processing INT1010455_0000.nii.gz
# processing INT1010459_0000.nii.gz
# processing INT1010460_0000.nii.gz
# processing INT1010463_0000.nii.gz
# processing INT1010467_0000.nii.gz
# processing INT1010468_0000.nii.gz
# processing INT1010473_0000.nii.gz
# processing INT1010475_0000.nii.gz
# processing INT1010476_0000.nii.gz
# processing INT1010477_0000.nii.gz
# processing INT1010478_0000.nii.gz
# processing INT1010484_0000.nii.gz
# processing INT1010486_0000.nii.gz
# processing INT1010487_0000.nii.gz
# processing INT1010492_0000.nii.gz
# processing INT1010495_0000.nii.gz
# processing INT1010496_0000.nii.gz
# processing INT1010499_0000.nii.gz
# processing INT1010503_0000.nii.gz
# processing INT1010508_0000.nii.gz
# processing INT1010513_0000.nii.gz
# processing INT1010514_0000.nii.gz
# processing INT1010516_0000.nii.gz
# processing INT1010520_0000.nii.gz
# processing INT1010521_0000.nii.gz
# processing INT1010522_0000.nii.gz
# processing INT1010529_0000.nii.gz
# processing INT1010533_0000.nii.gz
# processing INT1010534_0000.nii.gz
# processing INT1010536_0000.nii.gz
# processing INT1010537_0000.nii.gz
# processing INT1010539_0000.nii.gz
# processing INT1010540_0000.nii.gz
# processing INT1010541_0000.nii.gz
# processing INT1010543_0000.nii.gz
# processing INT1010548_0000.nii.gz
# processing INT1010556_0000.nii.gz
# processing INT1010557_0000.nii.gz
# processing INT1010559_0000.nii.gz
# processing INT1010561_0000.nii.gz
# processing INT1010563_0000.nii.gz
# processing INT1010564_0000.nii.gz
# processing INT1010567_0000.nii.gz
# processing INT1010570_0000.nii.gz
# processing INT1010571_0000.nii.gz
# processing INT1010572_0000.nii.gz
# processing INT1010576_0000.nii.gz
# processing INT1010577_0000.nii.gz
# processing INT1010579_0000.nii.gz
# processing INT1010580_0000.nii.gz
# processing INT1010581_0000.nii.gz
# processing INT1010582_0000.nii.gz
# processing INT1010583_0000.nii.gz
# processing INT1010584_0000.nii.gz
# processing INT1010585_0000.nii.gz
# processing INT1010586_0000.nii.gz
# processing INT1010591_0000.nii.gz
# processing INT1010592_0000.nii.gz
# processing INT1010593_0000.nii.gz
# processing INT1010595_0000.nii.gz
# processing INT1010596_0000.nii.gz
# processing INT1010597_0000.nii.gz
# processing INT1010598_0000.nii.gz
# processing INT1010599_0000.nii.gz
# processing INT1010600_0000.nii.gz
# processing INT1010605_0000.nii.gz
# processing INT1010606_0000.nii.gz
# processing INT1010607_0000.nii.gz
# processing INT1010608_0000.nii.gz
# processing INT1010609_0000.nii.gz
# processing INT1010611_0000.nii.gz
# processing INT1010612_0000.nii.gz
# processing INT1010613_0000.nii.gz
# processing INT1010614_0000.nii.gz
# processing INT1010616_0000.nii.gz
# processing INT1010617_0000.nii.gz
# processing INT1010620_0000.nii.gz
# processing INT1010622_0000.nii.gz
# processing INT1010623_0000.nii.gz
# processing INT1010624_0000.nii.gz
# processing INT1010627_0000.nii.gz
# processing INT1010634_0000.nii.gz
# processing INT1010635_0000.nii.gz
# processing INT1010636_0000.nii.gz
# processing INT1010637_0000.nii.gz
# processing INT1010638_0000.nii.gz
# processing INT1010641_0000.nii.gz
# processing INT1010642_0000.nii.gz
# processing INT1010643_0000.nii.gz
# processing INT1010645_0000.nii.gz
# done

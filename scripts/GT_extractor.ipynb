# %%
import os
import subprocess
import json
import dicom2nifti
import nibabel as nib
import numpy as np
import logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

os.sep = "/"
volume, pseudonym = "D:" + os.sep + "nsclc", os.sep + "tmp" + os.sep + "NSCLC"


input_suffix = os.sep + "tcia" + os.sep + "manifest-1710086948977" + os.sep + "NSCLC-Radiomics" + os.sep
input_stream = pseudonym + input_suffix
real_input = volume + input_suffix

output_suffix = os.sep + "data" + os.sep + "nnUNet_raw" + os.sep + "Dataset004_Corrected" + os.sep
output_ct_suffix = output_suffix + "imagesTr"
output_ct = pseudonym + output_ct_suffix
real_output_ct = volume + output_ct_suffix

output_labels_suffix = output_suffix + os.sep + "labelsTr"
output_labels =         pseudonym   + output_labels_suffix
real_output_labels =    volume      + output_labels_suffix

#get folders in real_input



def run_docker_command(input_path, name, format="nifti"):
    # Corrected Docker command with volume mapping and paths adjusted for Windows
    command = [
        "docker", "run", 
        "-v", f"{volume}:{pseudonym}", 
        "qiicr/dcmqi", 
        "segimage2itkimage", 
        "-t", format,
        "-p", name,
        "--outputDirectory", output_labels, 
        "--inputDICOM", input_path
    ]

    # Run the command
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

    # Check if the command was successful
    if result.returncode == 0:

        logging.info("Docker command executed successfully!")
        logging.info(f"Output:\n{result.stdout}")
    else:
        logging.error("Error running Docker command:")
        logging.error(f"Error output:\n{result.stderr}")

#check if input folder exists if not abort
if not os.path.exists(real_input):
    logging.error(f"input folder {real_input} does not exist")
    exit(1)

#check if output folders exist, if not create them
if not os.path.exists(real_output_ct):
    logging.warning(f"creating {real_output_ct}")
    os.makedirs(real_output_ct)
if not os.path.exists(real_output_labels):
    logging.warning(f"creating {real_output_labels}")
    os.makedirs(real_output_labels)



folders = os.listdir(real_input)


for folder in folders:
    #get folders in folder
    work_path = real_input + "/" + folder
    subfolder_patient = os.listdir(work_path)[0]
    work_path = work_path + "/" + subfolder_patient
    subfolders_cases = os.listdir(work_path)
    # in this list there is a folder called Segmentation, we want to put it at the end
    segmentation = [x for x in subfolders_cases if "Segmentation" in x]
    # remove it from the list and add it at the end
    subfolders_cases = [x for x in subfolders_cases if x not in segmentation]
    subfolders_cases.append(segmentation[0])
    
    logging.debug(f"order of subfolders: {subfolders_cases}")


    
    skipped_segmentation = False
    affine_matrix = None
    for subfolder_case in subfolders_cases:
        #check if already in output folder 

        if "Segmentation" in subfolder_case:
            input_command = input_stream + "/" + folder + "/" + subfolder_patient + "/" + subfolder_case + "/1-1.dcm"
            # check if already in output folder
            if os.path.exists(real_output_labels + "/" + folder + ".nii.gz"):
                logging.info(f"skipping {folder} as Segmentation already exists")
                skipped_segmentation = True
            elif skipped_segmentation is True:
                
                logging.warning(f"skipping {folder} as dicom conversion failed")
            else:
                logging.info(f"converting {folder} Segmentation to nifti")
                run_docker_command(input_command, folder)
        else:
            # check if already in output folder
            if os.path.exists(real_output_ct + "/" + folder + "_0000.nii.gz"):
                logging.info(f"skipping {folder} as CT already exists")
                
            else:
                try:
                    
                    logging.info(f"converting {folder} CT to nifti")
                    dicom2nifti.dicom_series_to_nifti(work_path + "/" + subfolder_case, real_output_ct+"/"+folder+"_0000.nii.gz")
                    logging.debug(f"CT converted to nifti")
                    # try loading the nifti file to see if it worked
                    temp = nib.load(real_output_ct + "/" + folder + "_0000.nii.gz")
                    logging.debug(f"CT loaded successfully")
                    #get affine matrix
                    affine_matrix_ct = temp.affine.copy()
                    logging.debug(f"affine matrix loaded successfully")
                    #get fdata
                    data = temp.get_fdata()
                    logging.debug(f"CT data loaded successfully")

                except:
                    # check if file was created and delete it
                    if os.path.exists(real_output_ct + "/" + folder + "_0000.nii.gz"):
                        logging.warning(f"deleting {real_output_ct + '/' + folder + '_0000.nii.gz'}")
                        os.remove(real_output_ct + "/" + folder + "_0000.nii.gz")
                        logging.warning(f"deleted {real_output_ct + '/' + folder + '_0000.nii.gz'}")
                    logging.warning(f"skipping {folder} as CT could not be converted or loaded")
                    skipped_segmentation = True
                    break

    if skipped_segmentation:
        continue
    meta_data_path = real_output_labels + "/" + folder + "-meta.json"
    with open(meta_data_path, "r") as file:
        meta_data = json.load(file)
    for segmentation in meta_data['segmentAttributes']:
        if 'Neoplasm' in segmentation[0]['SegmentLabel']:
            tumor_id = segmentation[0]['labelID']
    # elements are of name folder-x.nii.gz, find all of them
    files = os.listdir(real_output_labels)
    for file in files:
        if folder in file:
            if f"{tumor_id}.nii.gz" in file:
                #rename it as folder.nii.gz
                curr_label = real_output_labels + "/" + file
                new_label = real_output_labels + "/" + folder + ".nii.gz"
                os.rename(curr_label, new_label)

                seg = nib.load(new_label)
                data = seg.get_fdata()
                data[data == tumor_id] = 1
                data = np.flip(data, axis=1) # <------ !!! WARNING: this is a contingent solution based on how the DICOM SEG in the dataset and dcmqi work, this modification allows to see in the correct orientation both the npz files of nnunet and 3d slicer representation! if for you it works like shit, probably you need to comment this line
                new_seg = nib.Nifti1Image(data, affine_matrix_ct, seg.header) # use the affine matrix from the CT in order to have the same space
                nib.save(new_seg, new_label)
                
            else: #delete it
                #print(f"deleting {real_output_labels + '/' + file}")
                logging.info(f"deleting {real_output_labels + '/' + file}")
                os.remove(real_output_labels + "/" + file)
# Out:
# 2024-03-10 22:42:40,885 - WARNING - creating D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr
# 2024-03-10 22:42:40,894 - WARNING - creating D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr
# 2024-03-10 22:42:40,901 - DEBUG - order of subfolders: ['0.000000-NA-82046', '300.000000-Segmentation-9.554']
# 2024-03-10 22:42:40,902 - INFO - converting LUNG1-001 CT to nifti
# 2024-03-10 22:42:41,169 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:42:41,187 - INFO - Reading and sorting dicom files
# 2024-03-10 22:42:41,624 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-001_0000.nii.gz
# 2024-03-10 22:42:43,334 - DEBUG - CT converted to nifti
# 2024-03-10 22:42:43,335 - DEBUG - CT loaded successfully
# 2024-03-10 22:42:43,336 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:42:43,701 - DEBUG - CT data loaded successfully
# 2024-03-10 22:42:43,702 - INFO - converting LUNG1-001 Segmentation to nifti
# 2024-03-10 22:42:46,471 - INFO - Docker command executed successfully!
# 2024-03-10 22:42:46,471 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-001/09-18-2008-StudyID-NA-69331/300.000000-Segmentation-9.554/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 536
# Total frames with unique IPP: 134
# Total overlapping frames: 134
# Origin: [-249.512, -460.512, -681.5]
# Slice extent: 399
# Slice spacing: 3
# Will not merge segments: Splitting segments into 4 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-001-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-001-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-001-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-001-4.nii.gz ... done
#
# 2024-03-10 22:42:48,235 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-001-2.nii.gz
# 2024-03-10 22:42:48,237 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-001-3.nii.gz
# 2024-03-10 22:42:48,238 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-001-4.nii.gz
# 2024-03-10 22:42:48,240 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-001-meta.json
# 2024-03-10 22:42:48,241 - DEBUG - order of subfolders: ['1.000000-NA-61228', '300.000000-Segmentation-5.421']
# 2024-03-10 22:42:48,241 - INFO - converting LUNG1-002 CT to nifti
# 2024-03-10 22:42:48,674 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:42:48,689 - INFO - Reading and sorting dicom files
# 2024-03-10 22:42:48,940 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-002_0000.nii.gz
# 2024-03-10 22:42:50,289 - DEBUG - CT converted to nifti
# 2024-03-10 22:42:50,299 - DEBUG - CT loaded successfully
# 2024-03-10 22:42:50,299 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:42:50,577 - DEBUG - CT data loaded successfully
# 2024-03-10 22:42:50,577 - INFO - converting LUNG1-002 Segmentation to nifti
# 2024-03-10 22:42:53,656 - INFO - Docker command executed successfully!
# 2024-03-10 22:42:53,657 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-002/01-01-2014-StudyID-NA-85095/300.000000-Segmentation-5.421/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 666
# Total frames with unique IPP: 111
# Total overlapping frames: 111
# Origin: [-250.112, -250.112, -133.4]
# Slice extent: 330
# Slice spacing: 3
# Will not merge segments: Splitting segments into 6 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-002-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-002-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-002-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-002-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-002-5.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-002-6.nii.gz ... done
#
# 2024-03-10 22:42:53,658 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-002-1.nii.gz
# 2024-03-10 22:42:55,012 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-002-3.nii.gz
# 2024-03-10 22:42:55,014 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-002-4.nii.gz
# 2024-03-10 22:42:55,015 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-002-5.nii.gz
# 2024-03-10 22:42:55,017 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-002-6.nii.gz
# 2024-03-10 22:42:55,018 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-002-meta.json
# 2024-03-10 22:42:55,020 - DEBUG - order of subfolders: ['1.000000-NA-28595', '300.000000-Segmentation-2.316']
# 2024-03-10 22:42:55,020 - INFO - converting LUNG1-003 CT to nifti
# 2024-03-10 22:42:55,509 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:42:55,526 - INFO - Reading and sorting dicom files
# 2024-03-10 22:42:55,532 - INFO - Found sequence type: 4D
# 2024-03-10 22:42:55,532 - INFO - Creating data block
# 2024-03-10 22:42:55,533 - INFO - Creating block 1 of 2
# 2024-03-10 22:42:55,730 - INFO - Creating block 2 of 2
# 2024-03-10 22:42:56,016 - WARNING - Missing slices (slice count mismatch between timepoint 0 and 1)
# 2024-03-10 22:42:56,017 - WARNING - ---------------------------------------------------------
# 2024-03-10 22:42:56,017 - WARNING - (512, 512, 79)
# 2024-03-10 22:42:56,018 - WARNING - (512, 512, 28)
# 2024-03-10 22:42:56,019 - WARNING - ---------------------------------------------------------
# 2024-03-10 22:42:56,044 - WARNING - skipping LUNG1-003 as CT could not be converted or loaded
# 2024-03-10 22:42:56,049 - DEBUG - order of subfolders: ['0.000000-NA-20785', '300.000000-Segmentation-8.760']
# 2024-03-10 22:42:56,050 - INFO - converting LUNG1-004 CT to nifti
# 2024-03-10 22:42:56,574 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:42:56,592 - INFO - Reading and sorting dicom files
# 2024-03-10 22:42:56,942 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-004_0000.nii.gz
# 2024-03-10 22:42:58,441 - DEBUG - CT converted to nifti
# 2024-03-10 22:42:58,450 - DEBUG - CT loaded successfully
# 2024-03-10 22:42:58,450 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:42:58,759 - DEBUG - CT data loaded successfully
# 2024-03-10 22:42:58,760 - INFO - converting LUNG1-004 Segmentation to nifti
# 2024-03-10 22:43:01,476 - INFO - Docker command executed successfully!
# 2024-03-10 22:43:01,476 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-004/09-24-2006-StudyID-NA-27873/300.000000-Segmentation-8.760/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 570
# Total frames with unique IPP: 114
# Total overlapping frames: 114
# Origin: [-249.512, -249.512, -649]
# Slice extent: 339
# Slice spacing: 3
# Will not merge segments: Splitting segments into 5 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-004-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-004-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-004-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-004-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-004-5.nii.gz ... done
#
# 2024-03-10 22:43:01,477 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-004-1.nii.gz
# 2024-03-10 22:43:02,876 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-004-3.nii.gz
# 2024-03-10 22:43:02,877 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-004-4.nii.gz
# 2024-03-10 22:43:02,879 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-004-5.nii.gz
# 2024-03-10 22:43:02,881 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-004-meta.json
# 2024-03-10 22:43:02,882 - DEBUG - order of subfolders: ['1.000000-NA-68747', '300.000000-Segmentation-4.485']
# 2024-03-10 22:43:02,883 - INFO - converting LUNG1-005 CT to nifti
# 2024-03-10 22:43:03,300 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:43:03,314 - INFO - Reading and sorting dicom files
# 2024-03-10 22:43:03,538 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-005_0000.nii.gz
# 2024-03-10 22:43:04,756 - DEBUG - CT converted to nifti
# 2024-03-10 22:43:04,764 - DEBUG - CT loaded successfully
# 2024-03-10 22:43:04,764 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:43:05,000 - DEBUG - CT data loaded successfully
# 2024-03-10 22:43:05,001 - INFO - converting LUNG1-005 Segmentation to nifti
# 2024-03-10 22:43:07,654 - INFO - Docker command executed successfully!
# 2024-03-10 22:43:07,654 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-005/01-01-2014-StudyID-NA-93819/300.000000-Segmentation-4.485/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 546
# Total frames with unique IPP: 91
# Total overlapping frames: 91
# Origin: [-250.112, -250.112, -179.4]
# Slice extent: 270
# Slice spacing: 3
# Will not merge segments: Splitting segments into 6 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-005-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-005-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-005-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-005-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-005-5.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-005-6.nii.gz ... done
#
# 2024-03-10 22:43:07,655 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-005-1.nii.gz
# 2024-03-10 22:43:08,688 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-005-3.nii.gz
# 2024-03-10 22:43:08,690 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-005-4.nii.gz
# 2024-03-10 22:43:08,692 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-005-5.nii.gz
# 2024-03-10 22:43:08,694 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-005-6.nii.gz
# 2024-03-10 22:43:08,695 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-005-meta.json
# 2024-03-10 22:43:08,696 - DEBUG - order of subfolders: ['1.000000-NA-58122', '300.000000-Segmentation-0.379']
# 2024-03-10 22:43:08,697 - INFO - converting LUNG1-006 CT to nifti
# 2024-03-10 22:43:09,221 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:43:09,238 - INFO - Reading and sorting dicom files
# 2024-03-10 22:43:09,533 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-006_0000.nii.gz
# 2024-03-10 22:43:11,079 - DEBUG - CT converted to nifti
# 2024-03-10 22:43:11,087 - DEBUG - CT loaded successfully
# 2024-03-10 22:43:11,087 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:43:11,411 - DEBUG - CT data loaded successfully
# 2024-03-10 22:43:11,412 - INFO - converting LUNG1-006 Segmentation to nifti
# 2024-03-10 22:43:14,730 - INFO - Docker command executed successfully!
# 2024-03-10 22:43:14,731 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-006/01-01-2014-StudyID-NA-99263/300.000000-Segmentation-0.379/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 684
# Total frames with unique IPP: 114
# Total overlapping frames: 114
# Origin: [-250.112, -250.112, -194.9]
# Slice extent: 339
# Slice spacing: 3
# Will not merge segments: Splitting segments into 6 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-006-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-006-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-006-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-006-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-006-5.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-006-6.nii.gz ... done
#
# 2024-03-10 22:43:14,734 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-006-1.nii.gz
# 2024-03-10 22:43:19,586 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-006-3.nii.gz
# 2024-03-10 22:43:19,590 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-006-4.nii.gz
# 2024-03-10 22:43:19,594 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-006-5.nii.gz
# 2024-03-10 22:43:19,598 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-006-6.nii.gz
# 2024-03-10 22:43:19,604 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-006-meta.json
# 2024-03-10 22:43:19,607 - DEBUG - order of subfolders: ['0.000000-NA-67872', '300.000000-Segmentation-7.585']
# 2024-03-10 22:43:19,609 - INFO - converting LUNG1-007 CT to nifti
# 2024-03-10 22:43:20,736 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:43:20,818 - INFO - Reading and sorting dicom files
# 2024-03-10 22:43:22,144 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-007_0000.nii.gz
# 2024-03-10 22:43:26,661 - DEBUG - CT converted to nifti
# 2024-03-10 22:43:26,683 - DEBUG - CT loaded successfully
# 2024-03-10 22:43:26,685 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:43:27,527 - DEBUG - CT data loaded successfully
# 2024-03-10 22:43:27,528 - INFO - converting LUNG1-007 Segmentation to nifti
# 2024-03-10 22:43:30,839 - INFO - Docker command executed successfully!
# 2024-03-10 22:43:30,840 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-007/05-28-2010-NA-NA-36277/300.000000-Segmentation-7.585/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 774
# Total frames with unique IPP: 129
# Total overlapping frames: 129
# Origin: [-249.512, -436.512, -641.5]
# Slice extent: 384
# Slice spacing: 3
# Will not merge segments: Splitting segments into 6 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-007-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-007-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-007-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-007-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-007-5.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-007-6.nii.gz ... done
#
# 2024-03-10 22:43:30,842 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-007-1.nii.gz
# 2024-03-10 22:43:36,322 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-007-3.nii.gz
# 2024-03-10 22:43:36,325 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-007-4.nii.gz
# 2024-03-10 22:43:36,329 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-007-5.nii.gz
# 2024-03-10 22:43:36,333 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-007-6.nii.gz
# 2024-03-10 22:43:36,338 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-007-meta.json
# 2024-03-10 22:43:36,343 - DEBUG - order of subfolders: ['1.000000-NA-44475', '300.000000-Segmentation-4.647']
# 2024-03-10 22:43:36,347 - INFO - converting LUNG1-008 CT to nifti
# 2024-03-10 22:43:37,191 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:43:37,249 - INFO - Reading and sorting dicom files
# 2024-03-10 22:43:38,098 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-008_0000.nii.gz
# 2024-03-10 22:43:42,432 - DEBUG - CT converted to nifti
# 2024-03-10 22:43:42,456 - DEBUG - CT loaded successfully
# 2024-03-10 22:43:42,457 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:43:43,190 - DEBUG - CT data loaded successfully
# 2024-03-10 22:43:43,192 - INFO - converting LUNG1-008 Segmentation to nifti
# 2024-03-10 22:43:46,387 - INFO - Docker command executed successfully!
# 2024-03-10 22:43:46,388 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-008/01-01-2014-StudyID-NA-52421/300.000000-Segmentation-4.647/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 684
# Total frames with unique IPP: 114
# Total overlapping frames: 114
# Origin: [-250.112, -250.112, -193.4]
# Slice extent: 339
# Slice spacing: 3
# Will not merge segments: Splitting segments into 6 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-008-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-008-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-008-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-008-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-008-5.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-008-6.nii.gz ... done
#
# 2024-03-10 22:43:46,389 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-008-1.nii.gz
# 2024-03-10 22:43:51,332 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-008-3.nii.gz
# 2024-03-10 22:43:51,335 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-008-4.nii.gz
# 2024-03-10 22:43:51,338 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-008-5.nii.gz
# 2024-03-10 22:43:51,343 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-008-6.nii.gz
# 2024-03-10 22:43:51,347 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-008-meta.json
# 2024-03-10 22:43:51,353 - DEBUG - order of subfolders: ['1.000000-NA-63984', '300.000000-Segmentation-1.739']
# 2024-03-10 22:43:51,355 - INFO - converting LUNG1-009 CT to nifti
# 2024-03-10 22:43:52,215 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:43:52,280 - INFO - Reading and sorting dicom files
# 2024-03-10 22:43:53,116 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-009_0000.nii.gz
# 2024-03-10 22:43:57,250 - DEBUG - CT converted to nifti
# 2024-03-10 22:43:57,271 - DEBUG - CT loaded successfully
# 2024-03-10 22:43:57,272 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:43:57,907 - DEBUG - CT data loaded successfully
# 2024-03-10 22:43:57,909 - INFO - converting LUNG1-009 Segmentation to nifti
# 2024-03-10 22:44:00,594 - INFO - Docker command executed successfully!
# 2024-03-10 22:44:00,596 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-009/01-01-2014-StudyID-NA-54035/300.000000-Segmentation-1.739/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 525
# Total frames with unique IPP: 105
# Total overlapping frames: 105
# Origin: [-250.112, -250.112, -161.9]
# Slice extent: 312
# Slice spacing: 3
# Will not merge segments: Splitting segments into 5 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-009-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-009-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-009-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-009-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-009-5.nii.gz ... done
#
# 2024-03-10 22:44:00,597 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-009-1.nii.gz
# 2024-03-10 22:44:05,394 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-009-3.nii.gz
# 2024-03-10 22:44:05,399 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-009-4.nii.gz
# 2024-03-10 22:44:05,403 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-009-5.nii.gz
# 2024-03-10 22:44:05,410 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-009-meta.json
# 2024-03-10 22:44:05,418 - DEBUG - order of subfolders: ['1.000000-NA-08510', '300.000000-Segmentation-8.342']
# 2024-03-10 22:44:05,419 - INFO - converting LUNG1-010 CT to nifti
# 2024-03-10 22:44:06,252 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:44:06,311 - INFO - Reading and sorting dicom files
# 2024-03-10 22:44:07,027 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-010_0000.nii.gz
# 2024-03-10 22:44:10,412 - DEBUG - CT converted to nifti
# 2024-03-10 22:44:10,432 - DEBUG - CT loaded successfully
# 2024-03-10 22:44:10,434 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:44:11,139 - DEBUG - CT data loaded successfully
# 2024-03-10 22:44:11,140 - INFO - converting LUNG1-010 Segmentation to nifti
# 2024-03-10 22:44:14,134 - INFO - Docker command executed successfully!
# 2024-03-10 22:44:14,135 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-010/01-01-2014-StudyID-NA-54264/300.000000-Segmentation-8.342/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 546
# Total frames with unique IPP: 91
# Total overlapping frames: 91
# Origin: [-250.112, -250.112, -119.9]
# Slice extent: 270
# Slice spacing: 3
# Will not merge segments: Splitting segments into 6 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-010-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-010-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-010-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-010-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-010-5.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-010-6.nii.gz ... done
#
# 2024-03-10 22:44:14,136 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-010-1.nii.gz
# 2024-03-10 22:44:17,955 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-010-3.nii.gz
# 2024-03-10 22:44:17,959 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-010-4.nii.gz
# 2024-03-10 22:44:17,964 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-010-5.nii.gz
# 2024-03-10 22:44:17,969 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-010-6.nii.gz
# 2024-03-10 22:44:17,972 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-010-meta.json
# 2024-03-10 22:44:17,977 - DEBUG - order of subfolders: ['1.000000-NA-64032', '300.000000-Segmentation-575.3']
# 2024-03-10 22:44:17,979 - INFO - converting LUNG1-011 CT to nifti
# 2024-03-10 22:44:18,690 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:44:18,744 - INFO - Reading and sorting dicom files
# 2024-03-10 22:44:19,437 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-011_0000.nii.gz
# 2024-03-10 22:44:22,972 - DEBUG - CT converted to nifti
# 2024-03-10 22:44:22,992 - DEBUG - CT loaded successfully
# 2024-03-10 22:44:22,994 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:44:23,641 - DEBUG - CT data loaded successfully
# 2024-03-10 22:44:23,642 - INFO - converting LUNG1-011 Segmentation to nifti
# 2024-03-10 22:44:26,407 - INFO - Docker command executed successfully!
# 2024-03-10 22:44:26,408 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-011/01-01-2014-StudyID-NA-64935/300.000000-Segmentation-575.3/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 528
# Total frames with unique IPP: 88
# Total overlapping frames: 88
# Origin: [-250.112, -250.112, -199.9]
# Slice extent: 261
# Slice spacing: 3
# Will not merge segments: Splitting segments into 6 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-011-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-011-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-011-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-011-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-011-5.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-011-6.nii.gz ... done
#
# 2024-03-10 22:44:26,411 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-011-1.nii.gz
# 2024-03-10 22:44:30,406 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-011-3.nii.gz
# 2024-03-10 22:44:30,408 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-011-4.nii.gz
# 2024-03-10 22:44:30,411 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-011-5.nii.gz
# 2024-03-10 22:44:30,415 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-011-6.nii.gz
# 2024-03-10 22:44:30,420 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-011-meta.json
# 2024-03-10 22:44:30,430 - DEBUG - order of subfolders: ['1.000000-NA-36694', '300.000000-Segmentation-3.102']
# 2024-03-10 22:44:30,436 - INFO - converting LUNG1-012 CT to nifti
# 2024-03-10 22:44:31,348 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:44:31,407 - INFO - Reading and sorting dicom files
# 2024-03-10 22:44:32,278 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-012_0000.nii.gz
# 2024-03-10 22:44:36,585 - DEBUG - CT converted to nifti
# 2024-03-10 22:44:36,607 - DEBUG - CT loaded successfully
# 2024-03-10 22:44:36,609 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:44:37,434 - DEBUG - CT data loaded successfully
# 2024-03-10 22:44:37,436 - INFO - converting LUNG1-012 Segmentation to nifti
# 2024-03-10 22:44:40,887 - INFO - Docker command executed successfully!
# 2024-03-10 22:44:40,888 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-012/01-01-2014-StudyID-NA-42151/300.000000-Segmentation-3.102/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 654
# Total frames with unique IPP: 109
# Total overlapping frames: 109
# Origin: [-250.112, -250.112, -202.4]
# Slice extent: 324
# Slice spacing: 3
# Will not merge segments: Splitting segments into 6 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-012-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-012-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-012-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-012-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-012-5.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-012-6.nii.gz ... done
#
# 2024-03-10 22:44:40,889 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-012-1.nii.gz
# 2024-03-10 22:44:45,675 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-012-3.nii.gz
# 2024-03-10 22:44:45,679 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-012-4.nii.gz
# 2024-03-10 22:44:45,684 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-012-5.nii.gz
# 2024-03-10 22:44:45,687 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-012-6.nii.gz
# 2024-03-10 22:44:45,693 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-012-meta.json
# 2024-03-10 22:44:45,698 - DEBUG - order of subfolders: ['0.000000-NA-16008', '300.000000-Segmentation-0.809']
# 2024-03-10 22:44:45,701 - INFO - converting LUNG1-013 CT to nifti
# 2024-03-10 22:44:46,468 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:44:46,556 - INFO - Reading and sorting dicom files
# 2024-03-10 22:44:47,849 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-013_0000.nii.gz
# 2024-03-10 22:44:53,517 - DEBUG - CT converted to nifti
# 2024-03-10 22:44:53,550 - DEBUG - CT loaded successfully
# 2024-03-10 22:44:53,551 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:44:54,563 - DEBUG - CT data loaded successfully
# 2024-03-10 22:44:54,565 - INFO - converting LUNG1-013 Segmentation to nifti
# 2024-03-10 22:44:57,358 - INFO - Docker command executed successfully!
# 2024-03-10 22:44:57,359 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-013/05-25-2006-StudyID-NA-50081/300.000000-Segmentation-0.809/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 536
# Total frames with unique IPP: 134
# Total overlapping frames: 134
# Origin: [-249.512, -249.512, -720.5]
# Slice extent: 399
# Slice spacing: 3
# Will not merge segments: Splitting segments into 4 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-013-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-013-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-013-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-013-4.nii.gz ... done
#
# 2024-03-10 22:45:03,062 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-013-2.nii.gz
# 2024-03-10 22:45:03,066 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-013-3.nii.gz
# 2024-03-10 22:45:03,069 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-013-4.nii.gz
# 2024-03-10 22:45:03,074 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-013-meta.json
# 2024-03-10 22:45:03,078 - DEBUG - order of subfolders: ['1.000000-NA-30199', '300.000000-Segmentation-7.918']
# 2024-03-10 22:45:03,080 - INFO - converting LUNG1-014 CT to nifti
# 2024-03-10 22:45:03,777 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:45:03,828 - INFO - Reading and sorting dicom files
# 2024-03-10 22:45:03,854 - WARNING - Slice increment not consistent through all slices
# 2024-03-10 22:45:03,856 - WARNING - ---------------------------------------------------------
# 2024-03-10 22:45:03,858 - WARNING - [-250.112 -250.112  -61.9  ] [ 0.  0. -6.]
# 2024-03-10 22:45:03,859 - WARNING - [-250.112 -250.112  -58.9  ] [ 0.  0. -3.]
# 2024-03-10 22:45:03,860 - WARNING - Instance Number: 70
# 2024-03-10 22:45:03,861 - WARNING - ---------------------------------------------------------
# 2024-03-10 22:45:03,890 - WARNING - skipping LUNG1-014 as CT could not be converted or loaded
# 2024-03-10 22:45:03,893 - DEBUG - order of subfolders: ['1.000000-NA-22037', '300.000000-Segmentation-5.476']
# 2024-03-10 22:45:03,894 - INFO - converting LUNG1-015 CT to nifti
# 2024-03-10 22:45:04,589 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:45:04,605 - INFO - Reading and sorting dicom files
# 2024-03-10 22:45:04,889 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-015_0000.nii.gz
# 2024-03-10 22:45:06,302 - DEBUG - CT converted to nifti
# 2024-03-10 22:45:06,311 - DEBUG - CT loaded successfully
# 2024-03-10 22:45:06,312 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:45:06,601 - DEBUG - CT data loaded successfully
# 2024-03-10 22:45:06,601 - INFO - converting LUNG1-015 Segmentation to nifti
# 2024-03-10 22:45:09,249 - INFO - Docker command executed successfully!
# 2024-03-10 22:45:09,249 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-015/01-01-2014-StudyID-NA-04625/300.000000-Segmentation-5.476/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 468
# Total frames with unique IPP: 117
# Total overlapping frames: 117
# Origin: [-229.888, -229.888, -234]
# Slice extent: 348
# Slice spacing: 3
# Will not merge segments: Splitting segments into 4 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-015-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-015-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-015-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-015-4.nii.gz ... done
#
# 2024-03-10 22:45:10,613 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-015-2.nii.gz
# 2024-03-10 22:45:10,615 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-015-3.nii.gz
# 2024-03-10 22:45:10,617 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-015-4.nii.gz
# 2024-03-10 22:45:10,618 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-015-meta.json
# 2024-03-10 22:45:10,620 - DEBUG - order of subfolders: ['1.000000-NA-12178', '300.000000-Segmentation-2.191']
# 2024-03-10 22:45:10,620 - INFO - converting LUNG1-016 CT to nifti
# 2024-03-10 22:45:10,987 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:45:10,999 - INFO - Reading and sorting dicom files
# 2024-03-10 22:45:11,184 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-016_0000.nii.gz
# 2024-03-10 22:45:12,255 - DEBUG - CT converted to nifti
# 2024-03-10 22:45:12,264 - DEBUG - CT loaded successfully
# 2024-03-10 22:45:12,265 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:45:12,486 - DEBUG - CT data loaded successfully
# 2024-03-10 22:45:12,486 - INFO - converting LUNG1-016 Segmentation to nifti
# 2024-03-10 22:45:15,267 - INFO - Docker command executed successfully!
# 2024-03-10 22:45:15,268 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-016/01-01-2014-StudyID-NA-36302/300.000000-Segmentation-2.191/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 492
# Total frames with unique IPP: 82
# Total overlapping frames: 82
# Origin: [-250.112, -250.112, -94.4]
# Slice extent: 243
# Slice spacing: 3
# Will not merge segments: Splitting segments into 6 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-016-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-016-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-016-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-016-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-016-5.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-016-6.nii.gz ... done
#
# 2024-03-10 22:45:15,269 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-016-1.nii.gz
# 2024-03-10 22:45:16,193 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-016-3.nii.gz
# 2024-03-10 22:45:16,195 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-016-4.nii.gz
# 2024-03-10 22:45:16,197 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-016-5.nii.gz
# 2024-03-10 22:45:16,198 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-016-6.nii.gz
# 2024-03-10 22:45:16,199 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-016-meta.json
# 2024-03-10 22:45:16,200 - DEBUG - order of subfolders: ['1.000000-NA-06844', '300.000000-Segmentation-1.241']
# 2024-03-10 22:45:16,201 - INFO - converting LUNG1-017 CT to nifti
# 2024-03-10 22:45:16,743 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:45:16,759 - INFO - Reading and sorting dicom files
# 2024-03-10 22:45:17,034 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-017_0000.nii.gz
# 2024-03-10 22:45:18,613 - DEBUG - CT converted to nifti
# 2024-03-10 22:45:18,619 - DEBUG - CT loaded successfully
# 2024-03-10 22:45:18,620 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:45:18,934 - DEBUG - CT data loaded successfully
# 2024-03-10 22:45:18,935 - INFO - converting LUNG1-017 Segmentation to nifti
# 2024-03-10 22:45:22,010 - INFO - Docker command executed successfully!
# 2024-03-10 22:45:22,011 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-017/01-01-2014-StudyID-NA-37586/300.000000-Segmentation-1.241/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 615
# Total frames with unique IPP: 123
# Total overlapping frames: 123
# Origin: [-250.112, -250.112, -167.9]
# Slice extent: 366
# Slice spacing: 3
# Will not merge segments: Splitting segments into 5 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-017-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-017-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-017-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-017-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-017-5.nii.gz ... done
#
# 2024-03-10 22:45:22,012 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-017-1.nii.gz
# 2024-03-10 22:45:23,659 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-017-3.nii.gz
# 2024-03-10 22:45:23,661 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-017-4.nii.gz
# 2024-03-10 22:45:23,662 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-017-5.nii.gz
# 2024-03-10 22:45:23,664 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-017-meta.json
# 2024-03-10 22:45:23,665 - DEBUG - order of subfolders: ['1.000000-NA-45959', '300.000000-Segmentation-9.793']
# 2024-03-10 22:45:23,665 - INFO - converting LUNG1-018 CT to nifti
# 2024-03-10 22:45:24,207 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:45:24,222 - INFO - Reading and sorting dicom files
# 2024-03-10 22:45:24,466 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-018_0000.nii.gz
# 2024-03-10 22:45:25,885 - DEBUG - CT converted to nifti
# 2024-03-10 22:45:25,893 - DEBUG - CT loaded successfully
# 2024-03-10 22:45:25,894 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:45:26,169 - DEBUG - CT data loaded successfully
# 2024-03-10 22:45:26,170 - INFO - converting LUNG1-018 Segmentation to nifti
# 2024-03-10 22:45:29,186 - INFO - Docker command executed successfully!
# 2024-03-10 22:45:29,186 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-018/01-01-2014-StudyID-NA-55796/300.000000-Segmentation-9.793/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 570
# Total frames with unique IPP: 114
# Total overlapping frames: 114
# Origin: [-250.112, -250.112, -187.9]
# Slice extent: 339
# Slice spacing: 3
# Will not merge segments: Splitting segments into 5 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-018-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-018-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-018-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-018-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-018-5.nii.gz ... done
#
# 2024-03-10 22:45:29,186 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-018-1.nii.gz
# 2024-03-10 22:45:30,537 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-018-3.nii.gz
# 2024-03-10 22:45:30,540 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-018-4.nii.gz
# 2024-03-10 22:45:30,541 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-018-5.nii.gz
# 2024-03-10 22:45:30,543 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-018-meta.json
# 2024-03-10 22:45:30,544 - DEBUG - order of subfolders: ['1.000000-NA-30710', '300.000000-Segmentation-7.689']
# 2024-03-10 22:45:30,545 - INFO - converting LUNG1-019 CT to nifti
# 2024-03-10 22:45:31,007 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:45:31,024 - INFO - Reading and sorting dicom files
# 2024-03-10 22:45:31,293 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-019_0000.nii.gz
# 2024-03-10 22:45:32,972 - DEBUG - CT converted to nifti
# 2024-03-10 22:45:32,981 - DEBUG - CT loaded successfully
# 2024-03-10 22:45:32,982 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:45:33,344 - DEBUG - CT data loaded successfully
# 2024-03-10 22:45:33,345 - INFO - converting LUNG1-019 Segmentation to nifti
# 2024-03-10 22:45:37,121 - INFO - Docker command executed successfully!
# 2024-03-10 22:45:37,121 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-019/01-01-2014-StudyID-NA-29398/300.000000-Segmentation-7.689/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 505
# Total frames with unique IPP: 101
# Total overlapping frames: 101
# Origin: [-207.872, -207.872, -189]
# Slice extent: 300
# Slice spacing: 3
# Will not merge segments: Splitting segments into 5 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-019-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-019-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-019-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-019-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-019-5.nii.gz ... done
#
# 2024-03-10 22:45:37,123 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-019-1.nii.gz
# 2024-03-10 22:45:41,121 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-019-3.nii.gz
# 2024-03-10 22:45:41,127 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-019-4.nii.gz
# 2024-03-10 22:45:41,133 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-019-5.nii.gz
# 2024-03-10 22:45:41,139 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-019-meta.json
# 2024-03-10 22:45:41,142 - DEBUG - order of subfolders: ['1.000000-NA-97384', '300.000000-Segmentation-7.931']
# 2024-03-10 22:45:41,144 - INFO - converting LUNG1-020 CT to nifti
# 2024-03-10 22:45:42,005 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-10 22:45:42,071 - INFO - Reading and sorting dicom files
# 2024-03-10 22:45:42,627 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-020_0000.nii.gz
# 2024-03-10 22:45:45,237 - DEBUG - CT converted to nifti
# 2024-03-10 22:45:45,249 - DEBUG - CT loaded successfully
# 2024-03-10 22:45:45,250 - DEBUG - affine matrix loaded successfully
# 2024-03-10 22:45:45,538 - DEBUG - CT data loaded successfully
# 2024-03-10 22:45:45,539 - INFO - converting LUNG1-020 Segmentation to nifti
# 2024-03-10 22:45:48,831 - INFO - Docker command executed successfully!
# 2024-03-10 22:45:48,832 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-020/01-01-2014-StudyID-NA-91495/300.000000-Segmentation-7.931/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 648
# Total frames with unique IPP: 108
# Total overlapping frames: 108
# Origin: [-250.112, -250.112, -235.9]
# Slice extent: 321
# Slice spacing: 3
# Will not merge segments: Splitting segments into 6 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-020-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-020-2.nii.gz ... done
# ...
# 2024-03-11 00:10:37,655 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-363-4.nii.gz
# 2024-03-11 00:10:37,657 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-363-5.nii.gz
# 2024-03-11 00:10:37,659 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-363-meta.json
# 2024-03-11 00:10:37,662 - DEBUG - order of subfolders: ['0.000000-NA-10537', '300.000000-Segmentation-7.861']
# 2024-03-11 00:10:37,662 - INFO - converting LUNG1-364 CT to nifti
# 2024-03-11 00:10:38,235 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-11 00:10:38,257 - INFO - Reading and sorting dicom files
# 2024-03-11 00:10:38,664 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-364_0000.nii.gz
# 2024-03-11 00:10:40,423 - DEBUG - CT converted to nifti
# 2024-03-11 00:10:40,430 - DEBUG - CT loaded successfully
# 2024-03-11 00:10:40,431 - DEBUG - affine matrix loaded successfully
# 2024-03-11 00:10:40,783 - DEBUG - CT data loaded successfully
# 2024-03-11 00:10:40,785 - INFO - converting LUNG1-364 Segmentation to nifti
# 2024-03-11 00:10:44,175 - INFO - Docker command executed successfully!
# 2024-03-11 00:10:44,175 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-364/02-27-2010-NA-NA-09037/300.000000-Segmentation-7.861/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 670
# Total frames with unique IPP: 134
# Total overlapping frames: 134
# Origin: [-249.512, -403.512, -647]
# Slice extent: 399
# Slice spacing: 3
# Will not merge segments: Splitting segments into 5 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-364-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-364-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-364-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-364-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-364-5.nii.gz ... done
#
# 2024-03-11 00:10:44,177 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-364-1.nii.gz
# 2024-03-11 00:10:45,948 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-364-3.nii.gz
# 2024-03-11 00:10:45,950 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-364-4.nii.gz
# 2024-03-11 00:10:45,952 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-364-5.nii.gz
# 2024-03-11 00:10:45,953 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-364-meta.json
# 2024-03-11 00:10:45,955 - DEBUG - order of subfolders: ['0.000000-NA-67405', '300.000000-Segmentation-8.107']
# 2024-03-11 00:10:45,956 - INFO - converting LUNG1-365 CT to nifti
# 2024-03-11 00:10:46,531 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-11 00:10:46,551 - INFO - Reading and sorting dicom files
# 2024-03-11 00:10:46,924 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-365_0000.nii.gz
# 2024-03-11 00:10:48,785 - DEBUG - CT converted to nifti
# 2024-03-11 00:10:48,798 - DEBUG - CT loaded successfully
# 2024-03-11 00:10:48,799 - DEBUG - affine matrix loaded successfully
# 2024-03-11 00:10:49,142 - DEBUG - CT data loaded successfully
# 2024-03-11 00:10:49,144 - INFO - converting LUNG1-365 Segmentation to nifti
# 2024-03-11 00:10:52,258 - INFO - Docker command executed successfully!
# 2024-03-11 00:10:52,259 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-365/04-01-2010-NA-NA-26011/300.000000-Segmentation-8.107/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 670
# Total frames with unique IPP: 134
# Total overlapping frames: 134
# Origin: [-249.512, -440.512, -639.5]
# Slice extent: 399
# Slice spacing: 3
# Will not merge segments: Splitting segments into 5 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-365-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-365-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-365-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-365-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-365-5.nii.gz ... done
#
# 2024-03-11 00:10:52,262 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-365-1.nii.gz
# 2024-03-11 00:10:54,080 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-365-3.nii.gz
# 2024-03-11 00:10:54,083 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-365-4.nii.gz
# 2024-03-11 00:10:54,086 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-365-5.nii.gz
# 2024-03-11 00:10:54,089 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-365-meta.json
# 2024-03-11 00:10:54,091 - DEBUG - order of subfolders: ['0.000000-NA-58053', '300.000000-Segmentation-8.435']
# 2024-03-11 00:10:54,092 - INFO - converting LUNG1-366 CT to nifti
# 2024-03-11 00:10:55,204 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-11 00:10:55,399 - INFO - Reading and sorting dicom files
# 2024-03-11 00:10:56,378 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-366_0000.nii.gz
# 2024-03-11 00:11:00,571 - DEBUG - CT converted to nifti
# 2024-03-11 00:11:00,595 - DEBUG - CT loaded successfully
# 2024-03-11 00:11:00,595 - DEBUG - affine matrix loaded successfully
# 2024-03-11 00:11:01,361 - DEBUG - CT data loaded successfully
# 2024-03-11 00:11:01,362 - INFO - converting LUNG1-366 Segmentation to nifti
# 2024-03-11 00:11:05,017 - INFO - Docker command executed successfully!
# 2024-03-11 00:11:05,018 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-366/04-12-2010-NA-NA-44824/300.000000-Segmentation-8.435/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 670
# Total frames with unique IPP: 134
# Total overlapping frames: 134
# Origin: [-249.512, -443.512, -655]
# Slice extent: 399
# Slice spacing: 3
# Will not merge segments: Splitting segments into 5 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-366-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-366-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-366-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-366-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-366-5.nii.gz ... done
#
# 2024-03-11 00:11:05,022 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-366-1.nii.gz
# 2024-03-11 00:11:07,996 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-366-3.nii.gz
# 2024-03-11 00:11:07,997 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-366-4.nii.gz
# 2024-03-11 00:11:07,999 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-366-5.nii.gz
# 2024-03-11 00:11:08,001 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-366-meta.json
# 2024-03-11 00:11:08,003 - DEBUG - order of subfolders: ['0.000000-NA-70950', '300.000000-Segmentation-7.912']
# 2024-03-11 00:11:08,005 - INFO - converting LUNG1-367 CT to nifti
# 2024-03-11 00:11:08,638 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-11 00:11:08,663 - INFO - Reading and sorting dicom files
# 2024-03-11 00:11:09,081 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-367_0000.nii.gz
# 2024-03-11 00:11:11,185 - DEBUG - CT converted to nifti
# 2024-03-11 00:11:11,196 - DEBUG - CT loaded successfully
# 2024-03-11 00:11:11,196 - DEBUG - affine matrix loaded successfully
# 2024-03-11 00:11:11,610 - DEBUG - CT data loaded successfully
# 2024-03-11 00:11:11,610 - INFO - converting LUNG1-367 Segmentation to nifti
# 2024-03-11 00:11:15,185 - INFO - Docker command executed successfully!
# 2024-03-11 00:11:15,186 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-367/03-03-2010-NA-NA-79271/300.000000-Segmentation-7.912/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 670
# Total frames with unique IPP: 134
# Total overlapping frames: 134
# Origin: [-249.512, -448.512, -607]
# Slice extent: 399
# Slice spacing: 3
# Will not merge segments: Splitting segments into 5 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-367-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-367-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-367-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-367-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-367-5.nii.gz ... done
#
# 2024-03-11 00:11:15,187 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-367-1.nii.gz
# 2024-03-11 00:11:17,179 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-367-3.nii.gz
# 2024-03-11 00:11:17,181 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-367-4.nii.gz
# 2024-03-11 00:11:17,183 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-367-5.nii.gz
# 2024-03-11 00:11:17,184 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-367-meta.json
# 2024-03-11 00:11:17,187 - DEBUG - order of subfolders: ['0.000000-NA-84009', '300.000000-Segmentation-7.874']
# 2024-03-11 00:11:17,187 - INFO - converting LUNG1-368 CT to nifti
# 2024-03-11 00:11:17,818 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-11 00:11:17,844 - INFO - Reading and sorting dicom files
# 2024-03-11 00:11:18,262 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-368_0000.nii.gz
# 2024-03-11 00:11:20,129 - DEBUG - CT converted to nifti
# 2024-03-11 00:11:20,150 - DEBUG - CT loaded successfully
# 2024-03-11 00:11:20,152 - DEBUG - affine matrix loaded successfully
# 2024-03-11 00:11:20,500 - DEBUG - CT data loaded successfully
# 2024-03-11 00:11:20,500 - INFO - converting LUNG1-368 Segmentation to nifti
# 2024-03-11 00:11:23,952 - INFO - Docker command executed successfully!
# 2024-03-11 00:11:23,953 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-368/03-03-2010-NA-NA-28672/300.000000-Segmentation-7.874/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 655
# Total frames with unique IPP: 131
# Total overlapping frames: 131
# Origin: [-249.512, -440.512, -716.5]
# Slice extent: 390
# Slice spacing: 3
# Will not merge segments: Splitting segments into 5 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-368-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-368-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-368-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-368-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-368-5.nii.gz ... done
#
# 2024-03-11 00:11:23,955 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-368-1.nii.gz
# 2024-03-11 00:11:25,815 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-368-3.nii.gz
# 2024-03-11 00:11:25,816 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-368-4.nii.gz
# 2024-03-11 00:11:25,818 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-368-5.nii.gz
# 2024-03-11 00:11:25,820 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-368-meta.json
# 2024-03-11 00:11:25,823 - DEBUG - order of subfolders: ['0.000000-NA-45194', '300.000000-Segmentation-7.743']
# 2024-03-11 00:11:25,823 - INFO - converting LUNG1-369 CT to nifti
# 2024-03-11 00:11:26,458 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-11 00:11:26,482 - INFO - Reading and sorting dicom files
# 2024-03-11 00:11:26,922 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-369_0000.nii.gz
# 2024-03-11 00:11:28,695 - DEBUG - CT converted to nifti
# 2024-03-11 00:11:28,707 - DEBUG - CT loaded successfully
# 2024-03-11 00:11:28,708 - DEBUG - affine matrix loaded successfully
# 2024-03-11 00:11:29,095 - DEBUG - CT data loaded successfully
# 2024-03-11 00:11:29,096 - INFO - converting LUNG1-369 Segmentation to nifti
# 2024-03-11 00:11:32,472 - INFO - Docker command executed successfully!
# 2024-03-11 00:11:32,472 - INFO - Output:
# dcmqi repository URL: https://github.com/QIICR/dcmqi revision: d865fca tag:
# Loading DICOM SEG file /tmp/NSCLC/tcia/manifest-1710086948977/NSCLC-Radiomics//LUNG1-369/02-25-2010-NA-NA-41022/300.000000-Segmentation-7.743/1-1.dcm
# Row direction: 1 0 0
# Col direction: 0 1 0
# Z direction: 0 0 1
# Total frames: 670
# Total frames with unique IPP: 134
# Total overlapping frames: 134
# Origin: [-249.512, -383.512, -710.5]
# Slice extent: 399
# Slice spacing: 3
# Will not merge segments: Splitting segments into 5 groups
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-369-1.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-369-2.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-369-3.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-369-4.nii.gz ... done
# Writing itk image to /tmp/NSCLC/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-369-5.nii.gz ... done
#
# 2024-03-11 00:11:32,474 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-369-1.nii.gz
# 2024-03-11 00:11:34,415 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-369-3.nii.gz
# 2024-03-11 00:11:34,417 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-369-4.nii.gz
# 2024-03-11 00:11:34,419 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-369-5.nii.gz
# 2024-03-11 00:11:34,421 - INFO - deleting D:/nsclc/data/nnUNet_raw/Dataset004_Corrected//labelsTr/LUNG1-369-meta.json
# 2024-03-11 00:11:34,423 - DEBUG - order of subfolders: ['0.000000-NA-43329', '300.000000-Segmentation-7.601']
# 2024-03-11 00:11:34,424 - INFO - converting LUNG1-370 CT to nifti
# 2024-03-11 00:11:35,057 - INFO - WARNING: Assuming generic vendor conversion (ANATOMICAL)
# 2024-03-11 00:11:35,077 - INFO - Reading and sorting dicom files
# 2024-03-11 00:11:35,466 - INFO - Saving nifti to disk D:/nsclc/data/nnUNet_raw/Dataset004_Corrected/imagesTr/LUNG1-370_0000.nii.gz

# %%
# correctness check, for all the files in both folders, try loading, get fdata and check they have same dimensions and orientation
import os
import subprocess
import json
import dicom2nifti
import nibabel as nib
import numpy as np
import logging
from tqdm import tqdm
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

os.sep = "/"
volume, pseudonym = "D:" + os.sep + "nsclc", os.sep + "tmp" + os.sep + "NSCLC"


input_suffix = os.sep + "tcia" + os.sep + "manifest-1710086948977" + os.sep + "NSCLC-Radiomics" + os.sep
input_stream = pseudonym + input_suffix
real_input = volume + input_suffix

output_suffix = os.sep + "data" + os.sep + "nnUNet_raw" + os.sep + "Dataset004_Corrected" + os.sep
output_ct_suffix = output_suffix + "imagesTr"
output_ct = pseudonym + output_ct_suffix
real_output_ct = volume + output_ct_suffix

output_labels_suffix = output_suffix + os.sep + "labelsTr"
output_labels =         pseudonym   + output_labels_suffix
real_output_labels =    volume      + output_labels_suffix


ct_files = os.listdir(real_output_ct)

label_files = os.listdir(real_output_labels)

ct_files.sort()
label_files.sort()

mistakes_were_made = False
print("Checking for errors in input and output folders...")
#for n, file in enumerate(ct_files): <- make tqdm below
for n in tqdm(range(len(ct_files))):
    file = ct_files[n]

    # Check if file is in Segmentation folder, ct has name x_0000.nii.gz, label has name x.nii.gz
    #remove _0000.nii.gz
    file_name = file.split("_0000")[0]
    label_file = file_name + ".nii.gz"

    if label_file not in label_files:
        logging.warning(f"File {file} found in CT folder but not in Segmentation folder.")
        continue

    # Attempt to load CT file
    try:
        ct_path = os.path.join(real_output_ct, file)
        ct = nib.load(ct_path)
        ct_img = ct.get_fdata()
    except Exception as e:
        logging.error(f"Error loading CT file {file}: {str(e)}")
        #remove file from folder
        os.remove(ct_path)
        logging.warning(f"deleting {ct_path}")
        # remove segmentation file as well
        label_path = os.path.join(real_output_labels, label_file)
        os.remove(label_path)
        logging.warning(f"deleting {label_path}")
        mistakes_were_made = True
        continue  # Skip further checks if CT file couldn't be loaded

    # Attempt to load label file
    try:
        label_path = os.path.join(real_output_labels, label_file)
        label = nib.load(label_path)
    except Exception as e:
        logging.error(f"Error loading label file {file}: {str(e)}")
        mistakes_were_made = True
        continue  # Skip further checks if label file couldn't be loaded

    # Check if shapes are different
    if ct.shape != label.shape:
        logging.warning(f"File {file} has different shapes in CT and Segmentation folders.")
        mistakes_were_made = True
        #show orientation
    
    # Check if affine matrices are different
    if not np.allclose(ct.affine, label.affine):
        logging.warning(f"File {file} has different affine matrices in CT and Segmentation folders.")
        mistakes_were_made = True
        
        
        


if mistakes_were_made:
    logging.error("Errors were found in input and output folders. Please check the logs for details.")
    logging.error("Erroneous files may have been deleted. Run the script again to reprocess the data. Only the erroneous files will be reprocessed.")
else:
    logging.info("God is in his heaven, all is right with the world.")
# Out:
# Checking for errors in input and output folders...
# 100%|██████████| 401/401 [02:42<00:00,  2.47it/s]
# 2024-03-10 21:57:03,741 - INFO - God is in his heaven, all is right with the world.

# %%
import matplotlib.pyplot as plt
ct = nib.load(real_output_ct + "/LUNG1-088_0000.nii.gz")
seg = nib.load(real_output_labels + "/LUNG1-088.nii.gz")
ct_slice = ct.get_fdata()[:,:,87].copy()
seg_slice = seg.get_fdata()[:,:,87].copy()

#rotate both 90 degrees counter clockwise
ct_slice = np.rot90(ct_slice)
seg_slice = np.rot90(seg_slice)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.imshow(ct_slice, cmap="gray")
ax.imshow(seg_slice, alpha=0.5)


plt.show()
